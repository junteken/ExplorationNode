# %%
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.6/dist-packages (0.6.3)
# Requirement already satisfied: resampy>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.19.5)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.48.0)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.0.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.15.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from librosa) (0.22.2.post1)
# Requirement already satisfied: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa) (0.31.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba>=0.38.0->librosa) (51.3.3)

# %% [markdown]
# ### tf.data.Dataset.map함수로 등록되는 전처리 함수들은 모두 graph mode로 동작한다.
# ### Autograph가 동작하면서 type checking을 하면서 computational graph를 생성하는데 실제로 one_hot_label의
# ### parameter중에 하나인 wav 변수는 type이 tensor이다.
# ### tensor type은 기본적으로 librosa함수의 param으로 전달이 불가능하다. (type이 안맞기 때문에)
# ### type을 맞추기위한 tf.make_ndarray, tf.convert_to_tensor, tf.audio.convert_audio_dtype과 같은 여러가지
# ### type변환 연산자를 사용해서 시도해보았지만 계속 compile error발생
# ### 해결 방법은 tf.numpy_function을 이용해 일반 python code를 중간에 끼워넣은 방식을 제공하고 있다.
# ### 아래는 공식 문서에 나오는 가이드이다.
# ### Note that irrespective of the context in which map_func is defined (eager vs. graph),
# ### tf.data traces the function and executes it as a graph.
# ### To use Python code inside of the function you have a few options:
# ### 1) Rely on AutoGraph to convert Python code into an equivalent graph computation.
# ### The downside of this approach is that AutoGraph can convert some but not all Python code.
# ### 2) Use tf.py_function, which allows you to write arbitrary Python code but
# ### will generally result in worse performance

# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers
import librosa


def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D

def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    # 아래와 같이 librosa와 같은 외부 라이브러리를 graph mode로 동작하는 중간에 넣으려면 
    # tf.numpy_function과 같이 wrapping함수를 통해 넣어주어야 동작한다.
    wav = tf.numpy_function(func = w2s, inp =[wav], Tout =tf.float32)

    return wav, label

def w2s(wav):
    # wav = tf.make_ndarray(wav)
    # fft = np.abs(librosa.stft(wav.numpy(), n_fft=258))
    fft = np.abs(librosa.stft(wav, n_fft=258))
    # fft = tf.audio.convert_audio_dtype(fft, 'float32')
    # fft = tf.convert_to_tensor(fft, dtype=tf.float32)
    
    # 여기서 왜 reshape을 또 해주어야 하는지 이해가 안가는 부분이다.
    # 이미 fft의 shape이 [130, 126, 1]일텐데
    # graph mode, eager mode로 동작하는 메커니즘에 대해 좀더 학습이 필요해보인다. 
    fft = tf.reshape(fft, [130, 126, 1])

    return fft


def residual_model():
    # input_tensor = layers.Input(shape=(sr, 1))
    input_tensor = layers.Input(shape=(130, 126, 1))

    x = layers.Conv2D(32, (3,3), padding='same', activation='relu')(input_tensor)
    x = layers.Conv2D(32, (3,3), padding='same', activation='relu')(x)
    skip_1 = layers.MaxPool2D()(x)

    x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(skip_1)
    x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(x)
    x = tf.concat([x, skip_1], -1)
    skip_2 = layers.MaxPool2D()(x)

    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(skip_2)
    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
    x = tf.concat([x, skip_2], -1)
    skip_3 = layers.MaxPool2D()(x)

    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(skip_3)
    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
    x = tf.concat([x, skip_3], -1)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    output_tensor = layers.Dense(12)(x)

    model_wav_skip = tf.keras.Model(input_tensor, output_tensor)

    model_wav_skip.summary()

    return model_wav_skip

def Conv2D_model():

    # input_tensor = layers.Input(shape=(sr, 1))
    input_tensor = layers.Input(shape=(130, 126, 1))

    x = layers.Conv2D(32, (3,3), padding='same', activation='relu')(input_tensor)
    x = layers.Conv2D(32, (3,3), padding='same', activation='relu')(x)
    x = layers.MaxPool2D()(x)

    x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(64, (3,3), padding='same', activation='relu')(x)
    x = layers.MaxPool2D()(x)

    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(128, (3,3), padding='same', activation='relu')(x)
    x = layers.MaxPool2D()(x)

    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
    x = layers.Conv2D(256, (3,3), padding='same', activation='relu')(x)
    x = layers.MaxPool2D()(x)
    x = layers.Dropout(0.3)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    output_tensor = layers.Dense(12)(x)

    model_wav = tf.keras.Model(input_tensor, output_tensor)

    model_wav.summary()

    return model_wav




def draw_graph(history_wav):

    acc = history_wav.history['accuracy']
    val_acc = history_wav.history['val_accuracy']

    loss=history_wav.history['loss']
    val_loss=history_wav.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(8, 8))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')
    plt.show()

def train_2Dconv_n_show(model, checkpoint_dir, train_dataset, train_wav, test_dataset, test_wav):
    optimizer=tf.keras.optimizers.Adam(1e-4)
    model.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
                  optimizer=optimizer,
                  metrics=['accuracy'])

    cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                     save_weights_only=True,
                                                     monitor='val_loss',
                                                     mode='auto',
                                                     save_best_only=True,
                                                     verbose=1)

    history_wav = model.fit(train_dataset, epochs=max_epochs,
                            steps_per_epoch=len(train_wav) // batch_size,
                            validation_data=test_dataset,
                            validation_steps=len(test_wav) // batch_size,
                            callbacks=[cp_callback]
                            )

    draw_graph(history_wav)

    model.load_weights(checkpoint_dir)
    results = model.evaluate(test_dataset)

    return results

# %%
sr = 8000
# data_path = os.getcwd()+'/data/speech_wav_8000.npz'

data_path = '/content/drive/MyDrive/DL_Study/AIFFEL/speech/speech_wav_8000.npz'
speech_data = np.load(data_path)
checkpoint_dir = os.getcwd()+'/models/wav'

target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']
label_value = target_list
label_value.append('unknown')
label_value.append('silence')

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)

train_wav, test_wav, train_label, test_label = train_test_split(speech_data["wav_vals"],
                                                                label_data,
                                                                test_size=0.1,
                                                                shuffle=True)

batch_size = 32
max_epochs = 10

train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)

test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)


model_wav = Conv2D_model()
# model_wav = residual_model()

results = train_2Dconv_n_show(model_wav, checkpoint_dir, train_dataset, train_wav, test_dataset, test_wav)
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
inv_label_value = {v: k for k, v in label_value.items()}
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 130, 126, 1)]     0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 130, 126, 32)      320
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 130, 126, 32)      9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 65, 63, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 65, 63, 64)        18496
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 65, 63, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 31, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 31, 128)       73856
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 32, 31, 128)       147584
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 32, 31, 128)       147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 15, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 15, 256)       295168
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 16, 15, 256)       590080
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 16, 15, 256)       590080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 8, 7, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 7, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 14336)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               3670272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 5,583,724
# Trainable params: 5,583,212
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/10
# 1423/1423 [==============================] - 172s 115ms/step - loss: 1.2624 - accuracy: 0.5846 - val_loss: 0.3747 - val_accuracy: 0.8835
#
# Epoch 00001: val_loss improved from inf to 0.37471, saving model to /content/models/wav
# Epoch 2/10
# 1423/1423 [==============================] - 166s 116ms/step - loss: 0.3098 - accuracy: 0.9039 - val_loss: 0.2070 - val_accuracy: 0.9357
#
# Epoch 00002: val_loss improved from 0.37471 to 0.20701, saving model to /content/models/wav
# Epoch 3/10
# 1423/1423 [==============================] - 166s 116ms/step - loss: 0.1917 - accuracy: 0.9413 - val_loss: 0.1471 - val_accuracy: 0.9547
#
# Epoch 00003: val_loss improved from 0.20701 to 0.14712, saving model to /content/models/wav
# Epoch 4/10
# 1423/1423 [==============================] - 166s 117ms/step - loss: 0.1315 - accuracy: 0.9613 - val_loss: 0.1524 - val_accuracy: 0.9511
#
# Epoch 00004: val_loss did not improve from 0.14712
# Epoch 5/10
# 1423/1423 [==============================] - 165s 116ms/step - loss: 0.1011 - accuracy: 0.9701 - val_loss: 0.1255 - val_accuracy: 0.9557
#
# Epoch 00005: val_loss improved from 0.14712 to 0.12546, saving model to /content/models/wav
# Epoch 6/10
# 1423/1423 [==============================] - 166s 117ms/step - loss: 0.0817 - accuracy: 0.9758 - val_loss: 0.1348 - val_accuracy: 0.9565
#
# Epoch 00006: val_loss did not improve from 0.12546
# Epoch 7/10
# 1423/1423 [==============================] - 167s 117ms/step - loss: 0.0647 - accuracy: 0.9811 - val_loss: 0.1166 - val_accuracy: 0.9628
#
# Epoch 00007: val_loss improved from 0.12546 to 0.11656, saving model to /content/models/wav
# Epoch 8/10
# 1423/1423 [==============================] - 167s 117ms/step - loss: 0.0570 - accuracy: 0.9827 - val_loss: 0.1138 - val_accuracy: 0.9628
#
# Epoch 00008: val_loss improved from 0.11656 to 0.11381, saving model to /content/models/wav
# Epoch 9/10
# 1423/1423 [==============================] - 166s 116ms/step - loss: 0.0494 - accuracy: 0.9848 - val_loss: 0.1078 - val_accuracy: 0.9634
#
# Epoch 00009: val_loss improved from 0.11381 to 0.10785, saving model to /content/models/wav
# Epoch 10/10
# 1423/1423 [==============================] - 166s 116ms/step - loss: 0.0418 - accuracy: 0.9878 - val_loss: 0.1247 - val_accuracy: 0.9614
#
# Epoch 00010: val_loss did not improve from 0.10785
# 159/159 [==============================] - 13s 79ms/step - loss: 0.1077 - accuracy: 0.9635
# loss value: 0.108
# accuracy value: 96.3453%

# %% [markdown]
# ## STFT로 wav data를 변환해주니 val accuracy가 96%까지 올라왔다

# %%
model_wav = Conv2D_model()
optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
              optimizer=optimizer,
              metrics=['accuracy'])
model_wav.load_weights(checkpoint_dir)
results = model_wav.evaluate(test_dataset)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 130, 126, 1)]     0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 130, 126, 32)      320
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 130, 126, 32)      9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 65, 63, 32)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 65, 63, 64)        18496
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 65, 63, 64)        36928
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 32, 31, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 32, 31, 128)       73856
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 32, 31, 128)       147584
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 31, 128)       147584
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 15, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 16, 15, 256)       295168
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 16, 15, 256)       590080
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 15, 256)       590080
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 7, 256)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 7, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 14336)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               3670272
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_2 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 5,583,724
# Trainable params: 5,583,212
# Non-trainable params: 512
# _________________________________________________________________
# 159/159 [==============================] - 13s 80ms/step - loss: 0.1002 - accuracy: 0.9647

# %%
model_wav = residual_model()

results = train_2Dconv_n_show(model_wav, checkpoint_dir, train_dataset, train_wav, test_dataset, test_wav)
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 130, 126, 1) 0
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 130, 126, 32) 320         input_4[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 130, 126, 32) 9248        conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 65, 63, 32)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 65, 63, 64)   18496       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 65, 63, 64)   36928       conv2d_32[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 65, 63, 96)   0           conv2d_33[0][0]
#                                                                  max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 32, 31, 96)   0           tf.concat[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 31, 128)  110720      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 31, 128)  147584      conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 31, 128)  147584      conv2d_35[0][0]
# __________________________________________________________________________________________________
# tf.concat_1 (TFOpLambda)        (None, 32, 31, 224)  0           conv2d_36[0][0]
#                                                                  max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 16, 15, 224)  0           tf.concat_1[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 15, 256)  516352      max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 15, 256)  590080      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 15, 256)  590080      conv2d_38[0][0]
# __________________________________________________________________________________________________
# tf.concat_2 (TFOpLambda)        (None, 16, 15, 480)  0           conv2d_39[0][0]
#                                                                  max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 8, 7, 480)    0           tf.concat_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 7, 480)    0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 26880)        0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 256)          6881536     flatten_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 256)          1024        dense_6[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 256)          0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 12)           3084        activation_3[0][0]
# ==================================================================================================
# Total params: 9,053,036
# Trainable params: 9,052,524
# Non-trainable params: 512
# __________________________________________________________________________________________________
# Epoch 1/10
# 1423/1423 [==============================] - 208s 146ms/step - loss: 1.3692 - accuracy: 0.5561 - val_loss: 0.3875 - val_accuracy: 0.8821
#
# Epoch 00001: val_loss improved from inf to 0.38748, saving model to /content/models/wav
# Epoch 2/10
# 1423/1423 [==============================] - 323s 227ms/step - loss: 0.3272 - accuracy: 0.8986 - val_loss: 0.2094 - val_accuracy: 0.9365
#
# Epoch 00002: val_loss improved from 0.38748 to 0.20937, saving model to /content/models/wav
# Epoch 3/10
# 1423/1423 [==============================] - 279s 196ms/step - loss: 0.2026 - accuracy: 0.9388 - val_loss: 0.1642 - val_accuracy: 0.9492
#
# Epoch 00003: val_loss improved from 0.20937 to 0.16421, saving model to /content/models/wav
# Epoch 4/10
# 1423/1423 [==============================] - 215s 151ms/step - loss: 0.1406 - accuracy: 0.9586 - val_loss: 0.1481 - val_accuracy: 0.9533
#
# Epoch 00004: val_loss improved from 0.16421 to 0.14811, saving model to /content/models/wav
# Epoch 5/10
# 1423/1423 [==============================] - 172s 121ms/step - loss: 0.1063 - accuracy: 0.9701 - val_loss: 0.1453 - val_accuracy: 0.9523
#
# Epoch 00005: val_loss improved from 0.14811 to 0.14528, saving model to /content/models/wav
# Epoch 6/10
# 1423/1423 [==============================] - 234s 165ms/step - loss: 0.0820 - accuracy: 0.9764 - val_loss: 0.2032 - val_accuracy: 0.9341
#
# Epoch 00006: val_loss did not improve from 0.14528
# Epoch 7/10
# 1423/1423 [==============================] - 220s 155ms/step - loss: 0.0689 - accuracy: 0.9799 - val_loss: 0.1530 - val_accuracy: 0.9466
#
# Epoch 00007: val_loss did not improve from 0.14528
# Epoch 8/10
# 1423/1423 [==============================] - 260s 183ms/step - loss: 0.0573 - accuracy: 0.9831 - val_loss: 0.1088 - val_accuracy: 0.9642
#
# Epoch 00008: val_loss improved from 0.14528 to 0.10876, saving model to /content/models/wav
# Epoch 9/10
# 1423/1423 [==============================] - 197s 138ms/step - loss: 0.0480 - accuracy: 0.9855 - val_loss: 0.1204 - val_accuracy: 0.9602
#
# Epoch 00009: val_loss did not improve from 0.10876
# Epoch 10/10
# 1423/1423 [==============================] - 334s 235ms/step - loss: 0.0431 - accuracy: 0.9876 - val_loss: 0.1069 - val_accuracy: 0.9676
#
# Epoch 00010: val_loss improved from 0.10876 to 0.10687, saving model to /content/models/wav
# 159/159 [==============================] - 27s 168ms/step - loss: 0.1067 - accuracy: 0.9676
# loss value: 0.107
# accuracy value: 96.7602%

# %% [markdown]
# ### residual connection이 존재하는 network이 학습이 빠르다라고 알고 있는데 여기 결과는 학습속도가 느려서 이 부분도 의문이다.
